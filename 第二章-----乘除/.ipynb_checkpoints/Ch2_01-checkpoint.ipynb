# %%
num1 = 2
num2 = 3

# add two numbers
prod = num1*num2

# display the computation
print('The product of {0} and {1} is {2}'.format(num1, num2, prod))
# Out:
# The product of 2 and 3 is 6

# %% [markdown]
# ![image.png](attachment:42521b1e-106a-4f32-aadb-61a9cafe04b1.png)

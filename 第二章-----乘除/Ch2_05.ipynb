# %% [markdown]
# ## 逐项积
#     两个形状相同的向量或矩阵对应位置的乘积叫做逐项积
# ![image.png](attachment:799d3ddc-21a2-494b-91a7-c5b967e39bb1.png)
#
#     在代码中直接用*表示逐项相乘

# %%
import numpy as np
a = np.array([[1,2,3]])
b = np.array([[4,5,6]])
A = np.array([[1,2,3],[4,5,6]])
B = np.array([[1,1,1],[-1,-1,-1]])

# %%
print(f"a,b向量的逐项积为：{a*b}")
print(f"A,B矩阵的逐项积为：\n{A*B}")
# Out:
# a,b向量的逐项积为：[[ 4 10 18]]
# A,B矩阵的逐项积为：
# [[ 1  2  3]
#  [-4 -5 -6]]

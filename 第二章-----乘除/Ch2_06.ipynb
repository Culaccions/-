# %% [markdown]
# ## 矩阵乘法
#     矩阵相乘的前提是A的行数与B的列数相等
# ![image.png](attachment:6701692c-8fba-4250-85c1-7dec7eaa4a6e.png)
# ![image.png](attachment:b7784ded-78fe-494e-9700-367e31f987ce.png)
#     矩阵不满足交换律，就算满足，结果也不一定一样
# ![image.png](attachment:2123e92f-b4a6-410e-b6af-733f81cf7167.png)

# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])

B = np.array([[4, 2],
              [3, 1]])

# calculate matrix multiplication
C = A@B      #在numpy中用@来对两个矩阵进行相乘

# %%
print(C)
# Out:
# [[10  4]
#  [24 10]]

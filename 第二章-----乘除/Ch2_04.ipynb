# %% [markdown]
# ## 向量内积
#     向量内积结果为标量，向量内积又叫标量积或点积
#     向量内积的运算规则是，两个形状相同的向量，对应位置元素一一相乘，再求和

# %% [markdown]
# ![image.png](attachment:37dbb8e5-0a9c-470c-bb2e-0794d6bff74f.png)
# ![image.png](attachment:22ea9a7f-b029-47a1-bfa7-9cd896e714c8.png)
# ![image.png](attachment:70af60b4-4a8c-49ca-b09b-e0f9c5defd22.png)

# %% [markdown]
# 可以使用numpy.inner()来计算两个向量的内积
# ![image.png](attachment:3bb2b2b6-c8ba-4164-bbbe-4eb50f9d353a.png)

# %%
import numpy as np
a_row = np.array([[1, 2, 3]])
b_row = np.array([[4, 3, 2]])

a_dot_b = np.inner(a_row, b_row)

print(a_dot_b)
# Out:
# [[16]]
